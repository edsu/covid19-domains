# %% [markdown]
# # Shopify
#
# [Shopify](https://shopify.com) is a popular e-commerce platform for creating storefronts on the web that can accept payments for goods. According to the Wikipedia page:
#
# > The company reported that it had more than 1,000,000 businesses in approximately 175 countries using its platform as of June 2019, with total gross merchandise volume exceeding $41.1 billion for calendar 2018.
#
# Since we crawled the DomainTools domains and save their homepages in a WARC file, we can read it back and see which sites look like they have shopify content.
#
# WARC files record both the HTTP requests and responses. First lets just read the file as a gzipped text file and see if shopify appears anywhere in it.

# %%
import gzip

found = 0
for line in gzip.open('data/warc/domaintools-2020-04-13.warc.gz'):
    if b'shopify' in line:
        found += 1
        if found > 100:
            break
        print(line)
# Out:
# b'Set-Cookie: _shopify_y=ae45e9c8-4c8f-48c8-b746-3711d72c02c5; path=/; expires=Wed, 13 Apr 2022 22:27:30 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=a705248e-9ab3-4bc6-8428-5b7f69f3a2d6; path=/; expires=Wed, 13 Apr 2022 22:32:08 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=fbbdced4-9e7b-4936-8315-3a1b2ab0736f; path=/; expires=Wed, 13 Apr 2022 22:33:33 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=14afa1f5-44e5-4726-b642-0e38d53d41f7; path=/; expires=Wed, 13 Apr 2022 23:01:23 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=c857a98b-703d-4012-be71-dc416a304b92; path=/; expires=Wed, 13 Apr 2022 23:02:23 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=a3fac4bc-c84c-490e-babf-dae1c5b3d4be; path=/; expires=Wed, 13 Apr 2022 23:09:45 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=46f82c7f-2176-4518-aa96-593c0e0c53c7; path=/; expires=Wed, 13 Apr 2022 23:10:08 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=d3d270fbb1a7df3633b180947f0a5f60f1586777504; _shopify_y=46f82c7f-2176-4518-aa96-593c0e0c53c7\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=66b56a5b-10b1-41c0-8bb8-b06efbd81276; path=/; expires=Wed, 13 Apr 2022 23:11:06 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=08fea089-ffcf-4a2a-acca-44ee5d96cd9f; path=/; expires=Wed, 13 Apr 2022 23:11:28 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=7b25f7e0-d8ee-48bf-8b63-64e0b029a5ec; path=/; expires=Wed, 13 Apr 2022 23:20:31 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=62cf6afa-5a67-4c94-8d91-3e3bf74259be; path=/; expires=Wed, 13 Apr 2022 23:22:59 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=a7c5f8b7-3dc9-4b5a-ad31-fc55f1957ba2; path=/; expires=Wed, 13 Apr 2022 23:33:02 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=d3810f2a6d3a7d92022b9525bc7a69eb41586778877; _shopify_y=a7c5f8b7-3dc9-4b5a-ad31-fc55f1957ba2\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=2ca553e8-cead-46fa-8c15-e69056e5899e; path=/; expires=Wed, 13 Apr 2022 23:33:07 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=72797525-4241-4583-9414-8537f878eba0; path=/; expires=Wed, 13 Apr 2022 23:34:29 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=d2cd9dc8ebe912c2bf86ee97c3cd664531586778965; _shopify_y=72797525-4241-4583-9414-8537f878eba0\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=6b518d38-e22a-4bf6-92dd-663ae059cfff; path=/; expires=Wed, 13 Apr 2022 23:35:24 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=9c6535ad-9b9a-4daa-86f5-f02a87975db1; path=/; expires=Wed, 13 Apr 2022 23:37:53 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=dd2412bd35f87b6f4127029ac1347202b1586779168; _shopify_y=9c6535ad-9b9a-4daa-86f5-f02a87975db1\r\n'
# b'Set-Cookie: _shopify_y=c90056d5-3d00-4563-8ab4-36b82a4114d9; path=/; expires=Thu, 14 Apr 2022 00:03:01 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=ec734469-1377-4d20-a8cc-c9b14ca320c6; path=/; expires=Thu, 14 Apr 2022 00:09:47 GMT\r\n'
# b'Set-Cookie: _shopify_y=e2b54dcd-0527-405d-be06-f0197e83c5b9; path=/; expires=Thu, 14 Apr 2022 00:09:47 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=8fe30154-4acb-4758-9e3f-b716e91f7f00; path=/; expires=Thu, 14 Apr 2022 00:20:47 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=6cf8fd45-be09-45fe-8ec9-e60f01679cde; path=/; expires=Thu, 14 Apr 2022 00:31:22 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=ef62400c-9c8d-446d-aa12-990aa6b47ab1; path=/; expires=Thu, 14 Apr 2022 00:34:44 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=748bf675-e2b0-4f6a-967f-bc507691075e; path=/; expires=Thu, 14 Apr 2022 00:47:50 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=d242f99591094b80d3f112a74543407451586783366; _shopify_y=748bf675-e2b0-4f6a-967f-bc507691075e\r\n'
# b'Set-Cookie: _shopify_y=dba2b569-b4a5-4a54-9230-84edf5b8818c; path=/; expires=Thu, 14 Apr 2022 00:52:55 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=d403322e1e2bfd2f2a1c175bdbdf7e3fb1586783670; _shopify_y=dba2b569-b4a5-4a54-9230-84edf5b8818c\r\n'
# b'Set-Cookie: _shopify_y=a1cb7283-0162-4352-938c-aa6f2d894fa4; path=/; expires=Thu, 14 Apr 2022 01:00:37 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=dd510d730b364146651e04e68a8ca94061586784132; _shopify_y=a1cb7283-0162-4352-938c-aa6f2d894fa4\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'set-cookie: _shopify_y=1196d6be-95e1-4f55-9590-35c81700bc4f; path=/; expires=Thu, 14 Apr 2022 01:06:41 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=b0a755e4-cad8-49b2-afa5-6a23a847a8fa; path=/; expires=Thu, 14 Apr 2022 01:18:08 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Cookie: __cfduid=debd243496dac75d0d6939e843562572d1586785184; _shopify_y=b0a755e4-cad8-49b2-afa5-6a23a847a8fa\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=41fb57ad-60e8-45c4-9593-7cce1b98871c; path=/; expires=Thu, 14 Apr 2022 01:18:15 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=5b825e1d-42cd-42d6-b049-36dd708bce44; path=/; expires=Thu, 14 Apr 2022 01:33:37 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Set-Cookie: _shopify_y=53b92b06-c72e-40a3-a64e-d6b0f81b6c47; path=/; expires=Thu, 14 Apr 2022 01:41:58 GMT\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'
# b'Report-To: {"group":"network-errors","max_age":2592000,"endpoints":[{"url":"https://monorail-edge.shopifycloud.com/v1/reports/nel/20190325/shopify"}]}\r\n'

# %% [markdown]
# Alright we're in business! It looks like there are lots of examples of HTTP responses coming back that are setting a Shopify [cookie], specifically _shopify_y, which is a cookie Shopify use for [analytics](https://www.shopify.com/legal/cookies) tracking. Setting cookies is crucial for online purchases and click tracking. So let's walk through the responses looking for responses that do this. Let's start with just one shall we?
#
# We used warcio to write the WARC data and we can [follow the directions](https://github.com/webrecorder/warcio#reading-warc-records) for reading it. The confusing thing is that WARC request and response records themselves have headers, and they contain the actual HTTP request and response records as payloads. The URL that is being archived is available in the `WARC-Target-URI` WARC record header, and we can find our `Set-Cookie` header in the HTTP headers.
#
# As we find matches we can add them to a list for further processing without needing to go back to the WARC data.

# %%
from warcio.archiveiterator import ArchiveIterator

shopify_urls = []

with open('data/warc/domaintools-2020-04-13.warc.gz', 'rb') as stream:
    for record in ArchiveIterator(stream):
        
        # if it's a response and had http headers
        if record.rec_type == 'response' and record.http_headers:
            
            # this is the URL that we collected (based on the domaintools list)
            url = record.rec_headers.get_header('WARC-Target-URI')
            
            # now lets see if the response sets a cookie
            cookie = record.http_headers.get_header('Set-Cookie', '')
            
            # if it's one of our _shopify_y cookies print it out
            if '_shopify_y' in cookie:
                print(url)
                shopify_urls.append(url)
# Out:
# https://www.coronamasks.io/
# https://www.covid-19masken.de/
# https://firstcoronavirusresponseact.com/
# https://www.firstcoronavirusresponseact.com/
# https://www.covid19-sanitizers.com/
# https://www.covid19-stop.de/
# https://covid-19preparation.com/
# https://www.covid-19preparation.com/
# https://covid19-desinfectantes.com/
# https://www.covid19-desinfectantes.com/
# https://covidphilippines.com/
# https://www.covidphilippines.com/
# https://www.sars-cov-2-design.de/
# https://corona-shop-hamburg.de/
# https://www.covidsupplyusa.com/
# https://www.covidone9.co.uk/
# https://covid-19-t-shirt-shop.myshopify.com/
# https://covid-19-t-shirt-shop.myshopify.com/
# https://www.fk-covid19.com/
# https://www.covidrebel.com/
# https://www.customcovid.com/
# https://www.co-vid19store.com/
# https://freakyshoes.com/
# https://approvedcovid19tests.com.au/
# https://www.approvedcovid19tests.com.au/
# https://freakyshoes.com/
# https://covid-19familycare.com/
# https://www.covidclub2020.com/
# https://theanticoronavirusshop.com/
# https://www.theanticoronavirusshop.com/
# https://thecovidmasks.com/
# https://www.thecovidmasks.com/
# https://stopcoronavirusshop.co.nz/
# https://www.stopcoronavirusshop.co.nz/
# https://www.covid19homegoods.com/
# https://www.worldwidecoronavirus.org/
# https://www.coronaschutz-handel.de/
# https://apparelcovid19.com/
# https://www.apparelcovid19.com/
# https://www.everybodyvscovid.com/
# https://freakyshoes.com/
# https://www.detroitlifegear.com/collections/covid-19
# https://freakyshoes.com/
# https://freakyshoes.com/
# https://covid19supplyltd.com/
# https://www.covid19supplyltd.com/
# https://maskn95coronavirus.com/
# https://www.maskn95coronavirus.com/
# https://freakyshoes.com/
# https://acsienterprises.com/pages/covid19
# https://freakyshoes.com/
# https://freakyshoes.com/
# https://freakyshoes.com/
# https://www.anticovidmask.shop/
# https://coronavirusstore.org/
# https://www.coronavirusstore.org/
# https://covid19kits.store/
# https://www.covid19kits.store/
# https://lebicoronavirusmask.com/
# https://www.lebicoronavirusmask.com/
# https://fuckcoronavirusshop.com/
# https://www.fuckcoronavirusshop.com/
# https://coronaprotectmasks.com/
# https://www.coronaprotectmasks.com/
# https://coronavirusshop.shop/
# https://www.coronavirusshop.shop/
# https://www.rapidmedicalsystems.com/
# https://protectionfromcovid.com/
# https://www.protectionfromcovid.com/
# https://www.face-mask-coronavirus.com/
# https://covid19protectworld.com/
# https://www.covid19protectworld.com/
# https://www.skymasks.com.br/
# https://covid19shop.org/
# https://www.covid19shop.org/
# https://fuckyoucoronavirus.com.ar/
# https://www.fuckyoucoronavirus.com.ar/
# https://antiviruscorona.shop/
# https://www.antiviruscorona.shop/
# https://covid-defense.org/
# https://www.covid-defense.org/
# https://covid-19antibody.com/
# https://www.covid-19antibody.com/
# https://www.coronamaskcompany.com/
# https://corona-store.nl/
# https://www.corona-store.nl/
# https://www.anti-coronakits.com/
# https://coronavirussupport.us/
# https://www.coronavirussupport.us/
# https://masquescovid19.com/
# https://www.masquescovid19.com/
# https://covid19battleship.com/
# https://www.covid19battleship.com/
# https://www.covid19gifts.com/
# https://suppliescorona.com/
# https://www.suppliescorona.com/
# https://covid-19effect.com/
# https://www.covid-19effect.com/
# https://covid-test.co.za/
# https://www.covid-test.co.za/
# https://freakyshoes.com/
# https://www.coronapro.co.il/
# https://freakyshoes.com/
# https://www.fightcoronavirustime.com/
# https://covidtestkit.co.za/
# https://www.covidtestkit.co.za/
# https://freakyshoes.com/
# https://forbidthecovid.com/
# https://www.forbidthecovid.com/
# https://freakyshoes.com/
# https://freakyshoes.com/
# https://coronasafemask.net/
# https://www.coronasafemask.net/
# https://covid19ppe.co/
# https://www.covid19ppe.co/
# https://bye-covid19.com/
# https://www.bye-covid19.com/
# https://coronaprotection.ch/
# https://www.coronaprotection.ch/
# https://corona-protection.ch/
# https://www.corona-protection.ch/
# https://www.covid-19-normality.com/
# https://www.covid-19normality.com/
# https://coronamerchshop.com/
# https://www.coronamerchshop.com/
# https://covid-19testkits.co.za/
# https://www.covid-19testkits.co.za/
# https://stopcovids.com/
# https://www.stopcovids.com/
# https://covid-19essentialsupplies.com/
# https://coronaviruspandemicessentials.com/
# https://www.coronaviruspandemicessentials.com/
# https://covidninetee.com/
# https://www.covidninetee.com/
# https://kickcovid19.org/
# https://www.kickcovid19.org/
# https://www.wtfcorona2020.com/
# https://www.covidmask.de/
# https://coronavirustestkits.co.za/
# https://www.coronavirustestkits.co.za/
# https://koronavirusokaukes.lt/
# https://www.koronavirusokaukes.lt/
# https://curecorona2020.org/
# https://www.curecorona2020.org/
# https://covidcleanser.com/
# https://www.covidcleanser.com/
# https://joincoronavirusfight.org/
# https://www.joincoronavirusfight.org/
# https://covid19instatest.com/
# https://www.covid19instatest.com/
# https://coronatest-kit.de/
# https://www.coronatest-kit.de/
# https://coronakit.com.co/
# https://www.coronakit.com.co/
# https://coronavirususa.store/
# https://www.coronavirususa.store/
# https://corona-supplies.net/
# https://www.corona-supplies.net/
# https://coronaviruspreventions.world/
# https://www.coronaviruspreventions.world/
# https://buildcoronavirushospital.com/
# https://www.buildcoronavirushospital.com/
# https://covid19check.net/
# https://www.covid19check.net/
# https://topcovid19necessities.com/
# https://www.topcovid19necessities.com/
# https://www.covidlivesmatter.com/
# https://covid-19protectionmask.com/
# https://www.covid-19protectionmask.com/
# https://www.caronavirusmasks.com/
# https://anti-corona-virus.com/
# https://www.anti-corona-virus.com/
# https://www.fightcorona.in/
# https://coronavirus-protection.net/
# https://www.coronavirus-protection.net/
# https://coronaviruskills.com/
# https://www.coronaviruskills.com/
# https://getcoronavirusmask.co.uk/
# https://www.getcoronavirusmask.co.uk/
# https://coronavirusaid.life/
# https://www.coronavirusaid.life/
# https://stop-coronavirus.org/
# https://www.stop-coronavirus.org/
# https://shopcoronavirus.com/
# https://www.shopcoronavirus.com/
# https://protectfromwuhan.com/
# https://www.protectfromwuhan.com/
# https://coronavirus-defense.com/
# https://www.coronavirus-defense.com/
# https://anticorona-virus.com/
# https://www.anticorona-virus.com/
# https://coronavirusshield.ca/
# https://www.coronavirusshield.ca/
# https://www.healthandsafetygear.com/
# https://www.healthandsafetygear.com/
# https://coronavirusmerch.com/
# https://www.coronavirusmerch.com/
# https://www.killwuhanvirus.com/
# https://coronaviruspharma.com/
# https://www.coronaviruspharma.com/
# https://www.coronavirusus.com/
# https://coronavirusshop.com/
# https://www.coronavirusshop.com/
# https://combatcoronavirus.org/
# https://www.combatcoronavirus.org/
# https://survivethecoronavirus.com/
# https://www.survivethecoronavirus.com/
# https://coronavirusprotection.org/
# https://www.coronavirusprotection.org/
# https://nomorecoronavirus.com/
# https://www.nomorecoronavirus.com/
# https://maskforcoronavirus.com/
# https://www.maskforcoronavirus.com/
# https://coronavirususa.com/
# https://www.coronavirususa.com/

# %% [markdown]
# You can see a bit of duplication since some URLs redirect to their www equivalent. To join up this data with the DomainTools dataset lets get the naked domain again.

# %%
from urllib.parse import urlparse

def get_domain(url):
    u = urlparse(url)
    return u.netloc.replace('www.', '')

shopify_domains = set(map(get_domain, shopify_urls))
shopify_domains
# Out:
# {'19covidmask.com',
#  'acsienterprises.com',
#  'adioscorona.com',
#  'adioscoronavirus.com',
#  'americanmasks.myshopify.com',
#  'anti-corona-mask.com',
#  'anti-corona-virus.com',
#  'anti-corona.ml',
#  'anti-corona.nl',
#  'anti-coronakits.com',
#  'anti-coronavirus.org',
#  'anti-coronavirus.tech',
#  'anti-covid19.store',
#  'anti-cronavirusmask.com',
#  'antiagingbed.com',
#  'anticorona-virus.com',
#  'anticorona.co',
#  'anticoronagermsupply.com',
#  'anticoronaviru.com',
#  'anticoronavirus-masks.com',
#  'anticoronaviruscare.com',
#  'anticoronavirusstore.com',
#  'anticovid.store',
#  'anticovid19.fr',
#  'anticovidmask.shop',
#  'antiviruscorona.shop',
#  'apparelcovid19.com',
#  'approvedcovid19tests.com.au',
#  'beatthecorona.com',
#  'becoronavirusclean.com',
#  'bescherming-coronavirus.nl',
#  'brovid-19.com',
#  'buildcoronavirushospital.com',
#  'buycoronavirusgear.com',
#  'bye-covid19.com',
#  'caronavirusmasks.com',
#  'chinese-virus.com',
#  'clovid19viruskits.com',
#  'co-vid19store.com',
#  'combatcoronavirus.org',
#  'contrelecoronavirus.com',
#  'coromasks.com',
#  'corona-checker.nl',
#  'corona-doktor.de',
#  'corona-mask.fr',
#  'corona-merch.com',
#  'corona-n95-mask.com',
#  'corona-no-more.com',
#  'corona-protection.ch',
#  'corona-se-daro-na.com',
#  'corona-shop-hamburg.de',
#  'corona-store.nl',
#  'corona-supplies.net',
#  'corona-test-covid19.com',
#  'corona-viral.com',
#  'corona-virus-mask.org',
#  'corona-virus-masken.de',
#  'corona-virus-supply.com',
#  'corona-virusmasks.com',
#  'corona19masks.com',
#  'coronaantivirus.club',
#  'coronabeskyttelse.com',
#  'coronacarekits.com',
#  'coronacleanfreaks.com',
#  'coronacloak.com',
#  'coronadesgarcons.com',
#  'coronafighterusa.com',
#  'coronafree2020.com',
#  'coronagone.shop',
#  'coronahealthsupply.com',
#  'coronakit.com.co',
#  'coronamask-store.com',
#  'coronamask-usa.com',
#  'coronamaskcompany.com',
#  'coronamasks.io',
#  'coronamasks.shop',
#  'coronamerchshop.com',
#  'coronaminus.com',
#  'coronaoff.me',
#  'coronapro.co.il',
#  'coronaprotection.ch',
#  'coronaprotectmasks.com',
#  'coronasafemask.net',
#  'coronasafestore.net',
#  'coronasalvation.com',
#  'coronaschutz-handel.de',
#  'coronaschutz.shop',
#  'coronasecured.com',
#  'coronastopers.com',
#  'coronastrong.org',
#  'coronastrong20.com',
#  'coronasuperstore.com',
#  'coronasuppliez.com',
#  'coronasupply.co.uk',
#  'coronasupply.store',
#  'coronasupplystore.com',
#  'coronataisaku.com',
#  'coronatest-kit.de',
#  'coronatestkit.shop',
#  'coronavid.com',
#  'coronavirus-care.co',
#  'coronavirus-covid-19.ca',
#  'coronavirus-defense.com',
#  'coronavirus-market.shop',
#  'coronavirus-maskn95.com',
#  'coronavirus-protection.net',
#  'coronavirus-protezione.com',
#  'coronavirus-saftey-protection.com',
#  'coronavirus-t.com',
#  'coronavirus-tees.com',
#  'coronavirus-wholesale.com',
#  'coronavirus.biz.pl',
#  'coronavirusadieu.com',
#  'coronavirusaid.life',
#  'coronavirusanti.com',
#  'coronavirusbaby.net',
#  'coronavirusbescherming.be',
#  'coronavirusbestmask.com',
#  'coronaviruscontrol.co.uk',
#  'coronaviruscontrolcenter.com',
#  'coronaviruscovid19masks.com',
#  'coronavirusdefend.co',
#  'coronavirusessentials.co.uk',
#  'coronavirusfacecover.com',
#  'coronavirusfree.net',
#  'coronavirushelp.se',
#  'coronavirushomeinternet-com.myshopify.com',
#  'coronavirusinfo.shop',
#  'coronaviruskills.com',
#  'coronaviruskits.site',
#  'coronavirusmart.com',
#  'coronavirusmask.best',
#  'coronavirusmasken.com',
#  'coronavirusmaskn95.com',
#  'coronavirusmaskscovid19.com',
#  'coronavirusmasksdirect.com',
#  'coronavirusmaskshop.net',
#  'coronavirusmasksonline.com',
#  'coronavirusmerch.com',
#  'coronavirusmouthmask.com',
#  'coronavirusmusthave.com',
#  'coronavirusnederland.com',
#  'coronavirusonlineshop.com',
#  'coronaviruspandemicessentials.com',
#  'coronaviruspharma.com',
#  'coronaviruspreventing.com',
#  'coronaviruspreventioncenter.com',
#  'coronaviruspreventionproducts.com',
#  'coronaviruspreventions.world',
#  'coronaviruspreventionus.com',
#  'coronavirusprotect.net',
#  'coronavirusprotection.io',
#  'coronavirusprotection.org',
#  'coronavirusprotectionkitstore.com',
#  'coronavirusprotectivemasks.com',
#  'coronavirusrocks.com',
#  'coronavirussafekit.com',
#  'coronavirussafeproducts.com',
#  'coronavirussafetymask.com',
#  'coronavirussafetyprotection.com',
#  'coronavirusschweiz.ch',
#  'coronavirusshield.ca',
#  'coronavirusshop.com',
#  'coronavirusshop.shop',
#  'coronavirussmasks.com',
#  'coronavirussocks.com',
#  'coronavirusstore.org',
#  'coronavirusstudio.com',
#  'coronavirussupplies.com.au',
#  'coronavirussupplymart.com',
#  'coronavirussupport.us',
#  'coronavirussurvivalkit.store',
#  'coronavirustee.shop',
#  'coronavirustesten.nl',
#  'coronavirustestkit.info',
#  'coronavirustestkits.co.za',
#  'coronavirustp.com',
#  'coronavirusundies.com',
#  'coronavirusus.com',
#  'coronavirususa.com',
#  'coronavirususa.store',
#  'coronavius.com',
#  'coronavprotection.com',
#  'coronawinkel.nl',
#  'covid-19-normality.com',
#  'covid-19-t-shirt-shop.myshopify.com',
#  'covid-19antibody.com',
#  'covid-19effect.com',
#  'covid-19essentialsupplies.com',
#  'covid-19facemasks.org',
#  'covid-19familycare.com',
#  'covid-19mask.co',
#  'covid-19mask.org',
#  'covid-19masken.de',
#  'covid-19normality.com',
#  'covid-19preparation.com',
#  'covid-19protection.shop',
#  'covid-19protectionmask.com',
#  'covid-19protectionproduct.com',
#  'covid-19rapidresponse.com',
#  'covid-19testkits.co.za',
#  'covid-69.ca',
#  'covid-defense.org',
#  'covid-test.co.za',
#  'covid19-desinfectantes.com',
#  'covid19-sanitizers.com',
#  'covid19-stop.de',
#  'covid19battleship.com',
#  'covid19check.net',
#  'covid19clothing.com',
#  'covid19factsanddata.com',
#  'covid19gifts.com',
#  'covid19homegoods.com',
#  'covid19instatest.com',
#  'covid19kits.store',
#  'covid19mask.co',
#  'covid19ppe.co',
#  'covid19protectionstore.com',
#  'covid19protectworld.com',
#  'covid19shop.org',
#  'covid19supplyltd.com',
#  'covid19undies.co.uk',
#  'covid19undies.com',
#  'covid19viruskits.com',
#  'covid19virusprotection.com',
#  'covid19ware.com',
#  'covid420.com',
#  'covid9tees.com.au',
#  'covidcleanser.com',
#  'covidcleanx.com',
#  'covidclear.com',
#  'covidclub2020.com',
#  'coviddepot.com',
#  'covidfreezone.com',
#  'covidhalt.com',
#  'covidheartcompany.org',
#  'covidkit19.com',
#  'covidlivesmatter.com',
#  'covidmask.de',
#  'covidmask.org',
#  'covidmask.store',
#  'covidmaskprotection.com',
#  'covidmasks.net',
#  'covidninetee.com',
#  'covidone9.co.uk',
#  'covidpaper.com',
#  'covidphilippines.com',
#  'covidprevent.com',
#  'covidpreventionkit.com',
#  'covidprotect.com',
#  'covidreaction.com',
#  'covidrebel.com',
#  'covidsafemask.com',
#  'covidsafenow.com',
#  'covidsupplier.com',
#  'covidsupplyusa.com',
#  'covidsurvivor.club',
#  'covidtestkit.co.za',
#  'covidvirusbaby.com',
#  'covidvirusprep.com',
#  'curecorona.co',
#  'curecorona2020.org',
#  'curethecoronav.com',
#  'customcovid.com',
#  'detoxcoronavirus.com',
#  'detroitlifegear.com',
#  'doihavecorona.org',
#  'donate4corona.com',
#  'dontgetcorona.com',
#  'e-coronas.com',
#  'easycovid19test.com',
#  'endcovid19.co.uk',
#  'erasecovid.com',
#  'everybodyvscovid.com',
#  'face-mask-coronavirus.com',
#  'facemask-coronavirus.com',
#  'facemaskcoronaviruses.com',
#  'fckvrs.com',
#  'fight-corona.co.uk',
#  'fightagainstcorona.com',
#  'fightcorona-virus.com',
#  'fightcorona.in',
#  'fightcoronavirus.info',
#  'fightcoronavirus.net',
#  'fightcoronavirustime.com',
#  'fightcovid.shop',
#  'fightingcovid19.com',
#  'firstcoronavirusresponseact.com',
#  'fk-covid19.com',
#  'flattenthecoronavirus.com',
#  'forbidthecovid.com',
#  'forcovid.com',
#  'freakyshoes.com',
#  'fuck-corona-shop.com',
#  'fuckcoronavirusshop.com',
#  'fuckyoucoronavirus.com.ar',
#  'fundascoronavirus.com',
#  'getcoronavirusmask.co.uk',
#  'goodbyecoronavirus.com',
#  'healthandsafetygear.com',
#  'helpcoronavirus.ca',
#  'higienecoronavirus.com',
#  'icbcbeatcoronavirus.com',
#  'icoronamask.com',
#  'information-covid19.com',
#  'joincoronavirusfight.org',
#  'kickcovid19.org',
#  'killwuhanvirus.com',
#  'koronavirusokaukes.lt',
#  'laatcoronaweg.nl',
#  'lcorona.xyz',
#  'lebicoronavirusmask.com',
#  'lecoronavirus.fr',
#  'letsendcovid19.org',
#  'limitcoronavirus.com',
#  'mascarillacoronavirus.cl',
#  'mascarillas-covid.com',
#  'maskforcoronavirus.com',
#  'maskn95coronavirus.com',
#  'maskofcorona.com',
#  'masks-for-corona-virus.com',
#  'masksforcovid-19.com',
#  'masque-anti-coronavirus.com',
#  'masque-coronavirus.ch',
#  'masquescovid19.com',
#  'mercorona.com',
#  'naturalcoronaviruscure.com',
#  'noalcoronavirus.com',
#  'nomorecoronavirus.com',
#  'noshamecones.com',
#  'notocoronavirus.com',
#  'offcovid19.com',
#  'officialcoronavirusitalia.com',
#  'officialcovidmasks.com',
#  'packanticontagiocoronavirus.com',
#  'perthcoronavirus.com',
#  'prevent-coronavirus.store',
#  'prevention-corona.com',
#  'preventioncoronavirus.com',
#  'protectfromwuhan.com',
#  'protectioncoronavirus.co.uk',
#  'protectionfromcovid.com',
#  'quarante--ten.com',
#  'rapidmedicalsystems.com',
#  'sanidadcoronavirus.com',
#  'sars-cov-2-design.de',
#  'schutz-coronavirus.de',
#  'self-quarantined.com',
#  'shop-covid19.com',
#  'shopcoronavirus.com',
#  'skymasks.com.br',
#  'stop-corona.info',
#  'stop-coronavirus.org',
#  'stop-coronavirus.ro',
#  'stopcorona-virus.com',
#  'stopcoronavirusshop.co.nz',
#  'stopcovids.com',
#  'suppliescorona.com',
#  'survivethecoronavirus.com',
#  'tamponecoronavirus.com',
#  'terminate-coronavirus.com',
#  'test4covid.co.uk',
#  'testkitcoronavirus.com',
#  'testkitcovid19.co.uk',
#  'theanticoronavirusshop.com',
#  'thebestcoronamask.com',
#  'thecoronafacemask.com',
#  'thecoronaviruskit.com.au',
#  'thecovidmask.com',
#  'thecovidmasks.com',
#  'topcoronavirusmask.com',
#  'topcovid19necessities.com',
#  'trackingcorona.com',
#  'trumpgotcorona.com',
#  'udown.com',
#  'ukmask.myshopify.com',
#  'vermijdcoronavirus.nl',
#  'viruscoronashop.com',
#  'voorkomcoronavirus.nl',
#  'wefightcorona.com',
#  'wfhcorona.com',
#  'wholesalemedicalsupplier.com',
#  'wincoronavirus.com',
#  'worldwidecoronavirus.org',
#  'wtfcorona2020.com',
#  'yourcoronamask.com'}

# %% [markdown]
# Now we can join back up with the DomainTools dataset:

# %%
import pandas

df = pandas.read_csv('data/domaintools/2020-04-13.csv.gz',
    parse_dates=['created'], 
    sep='\t',
    names=['domain', 'created', 'risk'],
)
df.head()
# Out:
#                    domain    created  risk
# 0      covidcolour.online 2020-04-12    99
# 1  covid-19-test-kit.info 2020-04-12    99
# 2      quarantinecrew.xyz 2020-04-12    99
# 3           covidmemes.co 2020-04-12    99
# 4     quarantalne.website 2020-04-12    99

# %% [markdown]
# Now lets add a column of booleans to indicate if the domain was flagged as being handled by Shopify.

# %%
df['shopify'] = df.apply(lambda r: r.domain in shopify_domains, axis=1)

# %% [markdown]
# Now lets get a dataframe of just the shopify domains and their created and risk.

# %%
shopify = df[df['shopify'] == True]
shopify
# Out:
#                                  domain    created  risk  shopify
# 6543                     coronamasks.io 2020-04-07    99     True
# 9010                  covid-19masken.de 2020-04-06    99     True
# 13431   firstcoronavirusresponseact.com 2020-04-04    99     True
# 15400            covid19-sanitizers.com 2020-04-03    99     True
# 17217                   covid19-stop.de 2020-04-02    99     True
# ...                                 ...        ...   ...      ...
# 121506                quarante--ten.com 2020-03-05    97     True
# 122871                  covidone9.co.uk 2020-03-30    96     True
# 123792                 coronakit.com.co 2020-03-20    96     True
# 126998               trackingcorona.com 2020-02-22    95     True
# 128417                    wfhcorona.com 2020-03-13    94     True
#
# [371 rows x 4 columns]

# %% [markdown]
# It's not entirely clear if the *created* value is when the domain was created or when DomainTools started tracking it (they say it can be either). But it still could be interesting to see how they evolve over time.

# %%
import altair as alt

counts = shopify.created.value_counts().reset_index()
counts.columns = ['created', 'count']
counts

alt.Chart(counts, width=800, title="Shopify Domains Created/Tracked per Day").mark_bar().encode(
    alt.X("created:T", title="Days"),
    alt.Y('count:Q', title="Domains")
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Test Kits
#
# The New York Times [reported](https://www.nytimes.com/2020/03/24/business/coronavirus-ecommerce-sites.html) on March 24 that Shopify have started blocking Coronavirus related sites that are selling test kits. So lets take a pass through the archived data again and look for any pages that mention "test kit" in their content.

# %%
import re
import sys

test_kit_urls = []
with open('data/warc/domaintools-2020-04-13.warc.gz', 'rb') as stream:
    for record in ArchiveIterator(stream):
        
        # if it's a response and had http headers
        if record.rec_type == 'response' and record.http_headers:
            
            # this is the URL that we collected (based on the domaintools list)
            url = record.rec_headers.get_header('WARC-Target-URI')
            
            # limit to html content
            if record.http_headers and 'html' in record.http_headers.get_header('Content-Type', ''):
            
                content = record.content_stream().read().decode('utf8', errors='ignore')
                if re.search('test kit', content, re.IGNORECASE):
                    sys.stdout.write('.')
                    test_kit_urls.append(url)
# Out:
# ..............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
test_kit_domains = set(map(get_domain, test_kit_urls))
test_kit_domains
# Out:
# {'about.fb.com',
#  'acovid19test.com',
#  'adsone.group',
#  'alphacheckpoint.com',
#  'anti-coronavirusproducts.co.za',
#  'antibodiescheck.com',
#  'anticoronaviruswholesale.com',
#  'anticovid19.top',
#  'athenscovid19.com',
#  'bcov2019.live',
#  'besafe-from-covid.com',
#  'bestcovid19test.convertri.com',
#  'blokkx-covid19.com',
#  'breakingcoronavirus.com',
#  'buycovidtest.com',
#  'c19medicus.com',
#  'canada.ca',
#  'cannabisdomainfinder.com',
#  'caronavirus.supplies',
#  'casesofcoronavirus.com',
#  'certifycovidclear.com',
#  'chambercovidupdates.ky',
#  'cornavirus.app',
#  'corona-19.tech',
#  'corona-advice.info',
#  'corona-schnelltester.com',
#  'corona-virus-test.shop',
#  'corona19kit.com',
#  'corona19test.co.uk',
#  'corona20.in',
#  'corona2019.org',
#  'coronacide.com',
#  'coronacure.news',
#  'coronadetectionkit.com',
#  'coronadiseasetracker.com',
#  'coronaeq.com',
#  'coronafaq.org',
#  'coronafighter.cn',
#  'coronaidmd.com',
#  'coronalatestnewsupdates.com',
#  'coronamedicalsupplies.co',
#  'coronamedtest.com',
#  'coronameters.com',
#  'coronaprotect.online',
#  'coronaquicktest.es',
#  'coronaselftest.eu',
#  'coronaselftests.com',
#  'coronatest.biz',
#  'coronatestkit.in',
#  'coronatests.co.uk',
#  'coronavirs.org',
#  'coronaviru.zone',
#  'coronavirus-easy-test.com',
#  'coronavirus-home-test-kits.com',
#  'coronavirus-machine.com',
#  'coronavirus-products.com',
#  'coronavirus-rapidtest.store',
#  'coronavirus-test-kit.it',
#  'coronavirus-testing.org',
#  'coronavirus-testing.us',
#  'coronavirus-testingkits.com',
#  'coronavirus-tests-uk.com',
#  'coronavirus-update.me',
#  'coronavirus.camp',
#  'coronavirus.media',
#  'coronavirus.ventures',
#  'coronavirus123.com',
#  'coronavirus19testing.com',
#  'coronavirus19tests.com',
#  'coronavirusactiongroup.org',
#  'coronavirusaid.co',
#  'coronavirusalert.news',
#  'coronavirusathometestkits.com',
#  'coronavirusaustralia.info',
#  'coronavirusbloodtest.com',
#  'coronaviruschecklist.co',
#  'coronavirusconfirmed.com',
#  'coronavirusdrug.com',
#  'coronavirusemployeetestkits.com',
#  'coronaviruses.tech',
#  'coronavirusfactory.com',
#  'coronavirusguru.info',
#  'coronavirushazmat.info',
#  'coronavirushazmatsuit.com',
#  'coronavirushazmatsuit.info',
#  'coronavirushelpline.uk',
#  'coronavirushometest.us',
#  'coronavirushometestkits.com',
#  'coronavirushospitalsupplies.com',
#  'coronaviruskit.nl',
#  'coronaviruskittest.de',
#  'coronaviruslabtest.com',
#  'coronavirusmentor.com',
#  'coronavirusnewsnow.co',
#  'coronavirusoutbreak.us',
#  'coronaviruspatch.com',
#  'coronaviruspressers.com',
#  'coronavirusqa.com',
#  'coronavirusrapidkits.com',
#  'coronaviruss.in',
#  'coronavirusselftestingkits.com',
#  'coronavirustechandbook.com',
#  'coronavirustest.ca',
#  'coronavirustest.services',
#  'coronavirustestgear.com',
#  'coronavirustesting.nl',
#  'coronavirustesting.org',
#  'coronavirustestingkit.co.uk',
#  'coronavirustestingkit.com.au',
#  'coronavirustestingkits.nl',
#  'coronavirustestingkits.org',
#  'coronavirustestinguk.com',
#  'coronavirustestkit.co.uk',
#  'coronavirustestkit.eu',
#  'coronavirustestkit.life',
#  'coronavirustestkit.nl',
#  'coronavirustestkit.store',
#  'coronavirustestkit.top',
#  'coronavirustestkit2020.com',
#  'coronavirustestkits.nl',
#  'coronavirustestkituk.co.uk',
#  'coronavirustestpack.com',
#  'coronavirustestpack.info',
#  'coronavirusworld.rip',
#  'coronaviruus.com',
#  'coronoviruses.com',
#  'coronvirus19.com',
#  'cororatracking.com',
#  'covid-19-bloodtest.com',
#  'covid-19-home-test.com',
#  'covid-19-rapid-test-kit.com',
#  'covid-19-store.com',
#  'covid-19-testkit.org',
#  'covid-19.pictures',
#  'covid-19besttestkits.com',
#  'covid-19bloodtest.com',
#  'covid-19detector.com',
#  'covid-19leaders.com',
#  'covid-19newsroundup.com',
#  'covid-19online.co.uk',
#  'covid-19pharm.com',
#  'covid-19rapidtest.co.uk',
#  'covid-19rapidtestkit.today',
#  'covid-19selftest.co.uk',
#  'covid-19test-kit.com',
#  'covid-19watch.com',
#  'covid-at-home.info',
#  'covid-fighter.org',
#  'covid-local.org',
#  'covid-protectiveproducts.com',
#  'covid-rapid.com',
#  'covid-stat.live',
#  'covid19-change.org',
#  'covid19-eq.com',
#  'covid19-facemask.com',
#  'covid19-help.de',
#  'covid19-newsroom.com',
#  'covid19-phenomics.org',
#  'covid19-projections.com',
#  'covid19-safe.com',
#  'covid19-survey.com',
#  'covid19-symptoms.com',
#  'covid19-test-kit.co.uk',
#  'covid19-test-kit.com',
#  'covid19-test-supply.com',
#  'covid19-test.com',
#  'covid19-updates.co.uk',
#  'covid19.com.tr',
#  'covid19.info.tr',
#  'covid19.now.site',
#  'covid19advisory.com',
#  'covid19antibodytest.com',
#  'covid19antibodytesting.com',
#  'covid19bulksupply.com',
#  'covid19care.us',
#  'covid19checkkit.com',
#  'covid19dasboards.com',
#  'covid19dashboads.com',
#  'covid19dashbords.com',
#  'covid19data.com',
#  'covid19delivery.in',
#  'covid19detectionkits.com',
#  'covid19diag.com',
#  'covid19drivethru.com',
#  'covid19essentialservices.com',
#  'covid19globalsupplies.com',
#  'covid19globalsupplies.net',
#  'covid19healthcheck.org',
#  'covid19healthdiaries.com',
#  'covid19helpwa.org',
#  'covid19homerapidtesting.com',
#  'covid19hometest.com.au',
#  'covid19hometestkits.co.uk',
#  'covid19info.site',
#  'covid19kit.com.au',
#  'covid19kitsonline.com',
#  'covid19korea.com',
#  'covid19labtesting.com',
#  'covid19live.com',
#  'covid19losangeles.org',
#  'covid19masks.co.za',
#  'covid19medicalsupplier.com',
#  'covid19newsroundup.com',
#  'covid19nordic.com',
#  'covid19pandemic.solutions',
#  'covid19pr.com',
#  'covid19prescreen.co.za',
#  'covid19press.com',
#  'covid19protector.com',
#  'covid19rapidantibodytest.com',
#  'covid19rapidresulttestkit.com',
#  'covid19readings.com',
#  'covid19reponsefund.org',
#  'covid19responsefud.org',
#  'covid19responsefun.org',
#  'covid19responsfund.org',
#  'covid19resposefund.org',
#  'covid19safety.care',
#  'covid19sh.tk',
#  'covid19socialcaring.com',
#  'covid19stas.live',
#  'covid19staysafe.com',
#  'covid19taskforce.ca',
#  'covid19test.ca',
#  'covid19test.eu',
#  'covid19test.guru',
#  'covid19testandprotect.com',
#  'covid19testbox.com',
#  'covid19testing.co.za',
#  'covid19testingkits.org',
#  'covid19testkit.com.my',
#  'covid19testkit.shop',
#  'covid19testkit4u.com',
#  'covid19testkiti.com',
#  'covid19testkits.ca',
#  'covid19testpack.com',
#  'covid19testsandmasks.com',
#  'covid19tracker.ph',
#  'covid19treatments.org',
#  'covid19utah.com',
#  'covid19zone.info',
#  'covid1info.live',
#  'covid1responsefund.org',
#  'covidbloodtestkit.com',
#  'covidclean.com.au',
#  'covidguards.org',
#  'covidmeds.info',
#  'covidoctor.com',
#  'covidppemarket.com',
#  'covidpreprints.com',
#  'covidprotection.co.uk',
#  'covidresponsenow.com',
#  'covidtestathome.com',
#  'covidtestchina.com',
#  'covidtestkitnow.com',
#  'covidtestkits.biz',
#  'covidtestkits.co.nz',
#  'covidtestkits.uk',
#  'covidvirustest.co.uk',
#  'covidvirususa.com',
#  'cv2labs.com',
#  'dailycovid19post.com',
#  'daocoronavirus.com',
#  'docs.google.com',
#  'dohealths.com',
#  'dpcovid19.org',
#  'en.wikipedia.org',
#  'evm-corona.com',
#  'fhcovid19.com',
#  'fightcovid-19.info',
#  'fightingwithcorona.com',
#  'firstcovid19.com',
#  'freecoronavirustest.org',
#  'getcovid19kit.com',
#  'ggoglecovid19.com',
#  'gkorpstrategy.com',
#  'globalcomdir.com',
#  'goldenalliance-medical.com',
#  'haemokinesis-coronavirus.com',
#  'happycoronaending.com',
#  'healthsafetyproducts.eu',
#  'helpcovidindia.com',
#  'homecovidtest.co.uk',
#  'homecovidtest.com',
#  'hometestkitcoronavirus.com',
#  'idealrehabcare.com',
#  'indiabattlecorona.com',
#  'instantcovid19tests.com',
#  'iwcovid19.com',
#  'kits-covid19.com',
#  'kittestcovid19.com',
#  'knowcoronavirus.com',
#  'koronaviruslu.com',
#  'las-cruces.org',
#  'letsbattlecoronavirus.com',
#  'letsbeatcovid.clinic',
#  'letsbeatcovid.co.uk',
#  'letsfightcoronavirus.com',
#  'louvinmedical.com',
#  'mailchi.mp',
#  'mcov2019.live',
#  'mncovid19.in',
#  'mppcpharmacy.com',
#  'mycoronafight.com',
#  'mycoronavirusregistration.com',
#  'mycoronavirustestkit.co.uk',
#  'mycoronavirustestkit.com',
#  'mycoronavirustestkits.com',
#  'mydesignermasks.com',
#  'nccov2019.live',
#  'ncov20199.live',
#  'ncov20219.live',
#  'nocovidvirus.com',
#  'nomorecovid.co.za',
#  'nowcorona.com',
#  'nutri-link.co.uk',
#  'ohanaglobaltrade.com',
#  'onestep-covid-19test.info',
#  'orangecountycovid19.com',
#  'ourcovidtest.com',
#  'pakcorona.com',
#  'pakfightscorona.com',
#  'pblabsdistribution.com',
#  'pharmabel-test-coronavirus.com',
#  'pkcovid-19.com',
#  'pmcovid-19rapidtest.com.au',
#  'promedicalcare.de',
#  'prueba-covid19.com',
#  'pruebascoronavirus.mx',
#  'rapidmedicalsystems.com',
#  'rapidtest-covid19.com',
#  'rapidtestcovid-19.com',
#  'sa-coronavirus.co.za',
#  'sandglab.com',
#  'sars-cov-2test.com',
#  'sarscovid19test.com',
#  'scotscoop.com',
#  'selftestkitcoronavirus.com',
#  'serocovid.com',
#  'sespco.co.uk',
#  'shutdown-covid.com',
#  'signofcoronavirus.com',
#  'sirsupply.com',
#  'sites.google.com',
#  'spauldingdecon.com',
#  'stop-coronavirus.host',
#  'stopcoronafund.com',
#  'stopcovid19.com.hk',
#  'stopcovid2019.com',
#  'swanseacovid19.com',
#  'tableau.com',
#  'techagainstcovid.com',
#  'tescorona.com',
#  'test-coronavirus.eu',
#  'test-covid19.co.uk',
#  'test-for-coronavirus.com',
#  'test-kit-coronavirus.com',
#  'test-kit-covid19.com',
#  'testcoronavirus.nl',
#  'testcoronawirus.online',
#  'testcovid19.biz',
#  'testcovid19.me',
#  'testcovidcare.com',
#  'testkitcoronavirus.eu',
#  'testkitcoronavirus.nl',
#  'testkitforcoronavirus.co.uk',
#  'testkitscoronavirus.eu',
#  'testkitscoronavirus.nl',
#  'thankyouchinaforcovid19.com',
#  'theatlantic.com',
#  'thecoronaviruswar.net',
#  'thecovid-19.net',
#  'thehightechstore.com',
#  'trackcovid19.in',
#  'treat-covid19.com',
#  'treatmentforcorona.com',
#  'trumpcoronavirusmishandling.com',
#  'turkiyecovid19.com',
#  'viewcorona.com',
#  'viveracov2.com',
#  'vntestkit-covid19.com',
#  'whitmancovid19.com',
#  'wuhancoronaviruscure.com',
#  'wuhancoronaviruscure.info',
#  'wuhancoronavirusdrug.com',
#  'wuhancoronavirusdrug.info',
#  'x-covid.com',
#  'zapcovid19.com'}

# %% [markdown]
# Now we can look for the intersection between test kit doains and the shopify domains we identified earlier.

# %%
shopify_domains.intersection(test_kit_domains)
# Out:
# {'rapidmedicalsystems.com'}

# %% [markdown]
# Not bad, we only found one! But there are a lot out there.

# %%
len(test_kit_domains)
# Out:
# 388
